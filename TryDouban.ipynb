# %%
import requests
from bs4 import BeautifulSoup
import urllib
import re
import time

# %%
loginUrl = 'https://accounts.douban.com/login'
formData={
    "redir":"http://movie.douban.com/mine?status=collect",
    "form_email":"xxxxxxxxxxx",
    "form_password":'xxxxxxxxxxx',
    "login":u'登录'
}
headers = {"User-Agent":'Mozilla/5.0 (Windows NT 6.1)\
 AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36'}
r = requests.post(loginUrl,data=formData,headers=headers)
page = r.text
#print r.url
soup = BeautifulSoup(page,"html.parser")

# %%
loginUrl = 'https://accounts.douban.com/login'
formData={
    "redir":"http://movie.douban.com/mine?status=collect",
    "form_email":"xxxxxxxxxxx",
    "form_password":'xxxxxxxxxxx',
    "login":u'登录'
}
headers = {"User-Agent":'Mozilla/5.0 (Windows NT 6.1)\
 AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36'}
r = requests.post(loginUrl,data=formData,headers=headers)
page = r.text
#print r.url

'''获取验证码图片'''
#利用bs4获取captcha地址
soup = BeautifulSoup(page,"html.parser")
captchaAddr = soup.find('img',id='captcha_image')['src']
#利用正则表达式获取captcha的ID
reCaptchaID = r'<input type="hidden" name="captcha-id" value="(.*?)"/'
captchaID = re.findall(reCaptchaID,page)
#print captchaID
#保存到本地
urllib.request.urlretrieve(captchaAddr,"captcha.jpg")
captcha = input('please input the captcha: ')

formData['captcha-solution'] = captcha
formData['captcha-id'] = captchaID

r = requests.post(loginUrl,data=formData,headers=headers)
page = r.text
if r.url=='http://movie.douban.com/mine?status=collect':
    print ('Login successfully!!!')
    print ('我看过的电影','-'*60)
    #获取看过的电影
    soup = BeautifulSoup(page,"html.parser")
    result = soup.findAll('li',attrs={"class":"title"})
    #print result
    for item in result:
        print (item.find('a').get_text())
else:
    print ("failed!")

# %%
print(r.url)
print(formData)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="ua-windows ua-webkit" lang="zh-cmn-Hans">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="webkit" name="renderer"/>
# <meta content="always" name="referrer"/>
# <title>
#     我看过的电影(891)
# </title>
# <meta content="cZdR4xxR7RxmM4zE" name="baidu-site-verification">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Sun, 6 Mar 2005 01:00:00 GMT" http-equiv="Expires"/>
# <link href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://img3.doubanio.com/f/shire/da18e98a294047dd92298000fe2080b38efda2ae/css/douban.css" rel="stylesheet" type="text/css"/>
# <link href="https://img3.doubanio.com/f/shire/ae3f5a3e3085968370b1fc63afcecb22d3284848/css/separation/_all.css" rel="stylesheet" type="text/css"/>
# ...

# %%
lines =soup.findAll('div', { "class" : "info" })
print(lines)
# Out:
# [<div class="info">
# <h1>我看过的电影(891)</h1>
# <ul>
# <li><a href="https://movie.douban.com/people/26322881/">电影主页</a></li>
# <li><a href="https://movie.douban.com/people/26322881/reviews">影评</a></li>
# <li><a href="https://movie.douban.com/people/26322881/question">问答</a></li>
# <li><a href="https://movie.douban.com/people/26322881/do">在看</a></li>
# <li><a href="https://movie.douban.com/people/26322881/wish">想看</a></li>
# <li><a href="https://movie.douban.com/people/26322881/collect">看过</a></li>
# <li><a href="https://www.douban.com/people/26322881/doulists">豆列</a></li>
# <li><a href="https://movie.douban.com/ticket/mine">电影票</a></li>
# <li><a href="https://movie.douban.com/notifications">电影提醒</a></li>
# <li><a href="/settings/">设置</a></li>
# <li class="sep">|</li>
# <li><a href="https://www.douban.com/people/26322881/">豆瓣主页</a></li>
# </ul>
# </div>, <div class="info">
# <ul>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/25788426/">
# ...

# %%
for line in lines:
    em=line.find('em')
    if (em!=None):
        print(em.get_text())
    #print the comment
    comment=line.find('span',{'class':'comment'})
    if(comment !=None):
        print(comment.get_text())
    print('---------------------------------------------------')
    #print(line.find('em').get_text())
# Out:
# ---------------------------------------------------
# 电锯惊魂8：竖锯 / Jigsaw
# 真的无聊，里面的人物一点都不立体，最后那个镜头还抄袭了火锅店的小香肠八爪鱼
# ---------------------------------------------------
# 小丑回魂 / It
# 好看的成长片！就是视觉效果上比伴我同行刺激多了╮(╯▽╰)╭
# ---------------------------------------------------
# 悟空传
# 这么好的中二剧本，硬生生改成主打耍朋友的蒙太奇，每一段都接得让人摸不着头脑，一点关于佛性和猴子内心的思考都没留下╮(╯▽╰)╭
# ---------------------------------------------------
# 极盗车神 / Baby Driver
# 哇这个年轻人会赛车，哇他还会搞音乐，哇他还会跑酷，哇记忆力还超群。这么厉害的年轻人，梦想就是豪车美女，编剧真是把自己sy的产物拿出来晒了。
# ---------------------------------------------------
# 星际特工：千星之城 / Valérian and the City of a Thousand Planets
# 一部讲一对很酷的小情侣耍朋友的电影。
# ---------------------------------------------------
# 母女大战 / Snatched
# ---------------------------------------------------
# 异形：契约 / Alien: Covenant
# ---------------------------------------------------
# 权力的游戏 第六季 / Game of Thrones Season 6
# ---------------------------------------------------
# 权力的游戏 第七季 / Game of Thrones Season 7
# ...

# %%
for em in soup.find_all("em"):
    print(em.text)

# %%
comment= soup.findAll("span", { "class" : "comment" })
co=[]
for i in comment:
    co.append(i.get_text())
    
print(co)
# Out:
# []

# %% [markdown]
# ## References:
# http://blog.csdn.net/andrewseu/article/details/47253791

# %%
  ;window._GLOBAL_NAV = {
    USER_ID: "26322881",
    UPLOAD_AUTH_TOKEN: "26322881:c11c819d1175eae16143afbd61976ece78f8fda7",
    SSE_TOKEN: "4763dfddd2495657652df6ca74aec68a33becb80",
    SSE_TIMESTAMP: "1511300024",
    DOUBAN_URL: "https://www.douban.com",
    N_NEW_NOTIS: 0,
    N_NEW_DOUMAIL: 0
  };
